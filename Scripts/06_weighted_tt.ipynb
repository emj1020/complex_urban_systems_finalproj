# %%
import pandas as pd
import numpy as np

# %%
tt = pd.read_csv('../Data/commute_tt_results_v2.csv')
tt.head()
# Out:
#          geoid  ctlabel  boro_code  boro_name  ct2010  boro_ct2010 cdeligibil  \
# 0  36061009800     98.0          1  Manhattan    9800      1009800          I
# 1  36061010200    102.0          1  Manhattan   10200      1010200          I
# 2  36061010400    104.0          1  Manhattan   10400      1010400          I
# 3  36061011300    113.0          1  Manhattan   11300      1011300          I
# 4  36061013000    130.0          1  Manhattan   13000      1013000          I
#
#   ntacode                        ntaname  puma  ...  CBD13  CBD14 CBD15  \
# 0    MN19        Turtle Bay-East Midtown  3808  ...   21.0   28.0  22.0
# 1    MN17          Midtown-Midtown South  3807  ...   24.0   23.0  19.0
# 2    MN17          Midtown-Midtown South  3807  ...   23.0   29.0  17.0
# 3    MN17          Midtown-Midtown South  3807  ...   16.0   19.0  11.0
# 4    MN40  Upper East Side-Carnegie Hill  3805  ...   28.0   31.0  32.0
#
#    CBD16  CBD17  CBD18  CBD19  CBD20  CBD21  CBD22
# ...

# %%
# # #column for mean 
# tt['mean_to_cbd'] = tt.iloc[:, -22:].mean(axis=1)

# %%
# # #travel time to the closest cbd
# tt['closest_cbd'] = tt.iloc[:, -22:].min(axis=1)

# %%
#load cbd data 
cbd = pd.read_csv('../Data/NTA_CBD_final.csv')
cbd
# Out:
#     Unnamed: 0 ntacode      c000  area_km2  %_cbd_jobs  borocode   boroname  \
# 0            0    BK09   13119.0  0.161585    0.005953       3.0   Brooklyn
# 1            1    BK38   90452.0  0.336149    0.041043       3.0   Brooklyn
# 2            2    BK68    9567.0  0.164809    0.004341       3.0   Brooklyn
# 3            3    BK73    9870.0  0.194892    0.004479       3.0   Brooklyn
# 4            4    BX43   15124.0  0.248715    0.006863       2.0      Bronx
# 5            5    MN09   31654.0  0.178083    0.014363       1.0  Manhattan
# 6            6    MN13  205454.0  1.554135    0.093225       1.0  Manhattan
# 7            7    MN14   25866.0  0.350484    0.011737       1.0  Manhattan
# 8            8    MN15   41089.0  0.527848    0.018644       1.0  Manhattan
# 9            9    MN17  794888.0  2.804878    0.360682       1.0  Manhattan
# 10          10    MN19  183391.0  1.165173    0.083214       1.0  Manhattan
# ...

# %%
#cbd1*%jobcbd1+

# %%
weight = pd.DataFrame()
for i in range(22):
    weight['w_tt_{}'.format(i+1)] = (tt.loc[:, 'CBD{}'.format(i+1)]*cbd['%_cbd_jobs'][i])

tt['w_tt'] = weight.sum(axis=1)
tt
# Out:
#             geoid  ctlabel  boro_code  boro_name  ct2010  boro_ct2010  \
# 0     36061009800     98.0          1  Manhattan    9800      1009800
# 1     36061010200    102.0          1  Manhattan   10200      1010200
# 2     36061010400    104.0          1  Manhattan   10400      1010400
# 3     36061011300    113.0          1  Manhattan   11300      1011300
# 4     36061013000    130.0          1  Manhattan   13000      1013000
# ...           ...      ...        ...        ...     ...          ...
# 2036  36005007300     73.0          2      Bronx    7300      2007300
# 2037  36005005100     51.0          2      Bronx    5100      2005100
# 2038  36005006300     63.0          2      Bronx    6300      2006300
# 2039  36081001900     19.0          4     Queens    1900      4001900
# 2040  36081017100    171.0          4     Queens   17100      4017100
#
#      cdeligibil ntacode                               ntaname  puma  ...  \
# ...

# %%
tt.iloc[:, -25:]
# Out:
#       area_km2                                formatted  CBD1  CBD2  CBD3  \
# 0     0.177075   40.75578797405885%2C-73.96777472301176  40.0  33.0  45.0
# 1     0.172893      40.759423723208%2C-73.9744493813563  37.0  30.0  42.0
# 2     0.173228  40.760778939480964%2C-73.97767289767248  38.0  29.0  43.0
# 3     0.175672     40.754775073606%2C-73.98786992507925  24.0  28.0  29.0
# 4     0.178202  40.772735996496955%2C-73.96473354620095  46.0  41.0  46.0
# ...        ...                                      ...   ...   ...   ...
# 2036  0.140062  40.814674574259094%2C-73.90938831207234  54.0  54.0  64.0
# 2037  0.511666  40.813192247604434%2C-73.92758489210354  51.0  46.0  55.0
# 2038  1.058782   40.82381487581867%2C-73.92841536399114  54.0  49.0  57.0
# 2039  0.871605   40.74855464500757%2C-73.94501085832961  43.0  35.0  32.0
# 2040  1.243047   40.74975914839509%2C-73.92549714660441  52.0  47.0  45.0
#
#       CBD4  CBD5  CBD6  CBD7  CBD8  ...  CBD14  CBD15  CBD16  CBD17  CBD18  \
# ...

# %%
# #column for mean 
tt['mean_tt'] =tt.iloc[:, -23:-1].mean(axis=1)
tt['min_tt'] =tt.iloc[:, -24:-2].min(axis=1)

# %%
tt.iloc[:, -25:]
# Out:
#       CBD1  CBD2  CBD3  CBD4  CBD5  CBD6  CBD7  CBD8  CBD9  CBD10  ...  CBD16  \
# 0     40.0  33.0  45.0  28.0  57.0  31.0  19.0  28.0  18.0   14.0  ...   23.0
# 1     37.0  30.0  42.0  26.0  54.0  27.0  15.0  25.0  14.0   10.0  ...   20.0
# 2     38.0  29.0  43.0  27.0  50.0  24.0  16.0  18.0  14.0   12.0  ...   21.0
# 3     24.0  28.0  29.0  20.0  51.0  18.0  12.0  10.0  13.0    7.0  ...   15.0
# 4     46.0  41.0  46.0  37.0  53.0  37.0  32.0  17.0  34.0   26.0  ...   32.0
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...    ...
# 2036  54.0  54.0  64.0  53.0  50.0  36.0  45.0  32.0  44.0   37.0  ...   47.0
# 2037  51.0  46.0  55.0  40.0  40.0  38.0  37.0  31.0  40.0   30.0  ...   43.0
# 2038  54.0  49.0  57.0  48.0  33.0  37.0  36.0  32.0  36.0   31.0  ...   39.0
# 2039  43.0  35.0  32.0  31.0  60.0  33.0  22.0  29.0  21.0   17.0  ...   26.0
# 2040  52.0  47.0  45.0  43.0  73.0  46.0  37.0  43.0  36.0   29.0  ...   39.0
#
# ...

# %%
#Sanity check
# count=0
# tot=0
# for i in cbd['%_cbd_jobs']:
#     print(i,tt.iloc[0, -25:][count])
#     tot+=i*tt.iloc[0, -25:][count]
#     count+=1
# tot
# Out:
# 0.005952772583577717 40.0
# 0.041042776562982816 33.0
# 0.004341045453699826 45.0
# 0.0044785323119073146 28.0
# 0.006862545358185028 57.0
# 0.014363066038613388 31.0
# 0.09322516490482324 19.0
# 0.01173674942044525 28.0
# 0.01864421622735153 18.0
# 0.3606820255671106 14.0
# 0.08321403436808454 3.0
# 0.059992367891237464 12.0
# 0.013190570851787806 21.0
# 0.0028345887895121573 28.0
# 0.02557028686655653 22.0
# 0.09029619569779572 23.0
# 0.1083400980195086 27.0
# 0.009789699557183416 25.0
# 0.018246275716962204 15.0
# 0.011150501827032457 19.0
# 0.009100904010124115 13.0
# 0.006945581975518264 38.0

# %%
tt.columns
# Out:
# Index(['geoid', 'ctlabel', 'boro_code', 'boro_name', 'ct2010', 'boro_ct2010',
#        'cdeligibil', 'ntacode', 'ntaname', 'puma', 'shape_leng', 'shape_area',
#        'geometry', 'Bus_Access', 'Subway_Access', 'Bus_Count', 'Subway_Count',
#        'Center_Lat', 'Center_Lon', 'area_km2', 'formatted', 'CBD1', 'CBD2',
#        'CBD3', 'CBD4', 'CBD5', 'CBD6', 'CBD7', 'CBD8', 'CBD9', 'CBD10',
#        'CBD11', 'CBD12', 'CBD13', 'CBD14', 'CBD15', 'CBD16', 'CBD17', 'CBD18',
#        'CBD19', 'CBD20', 'CBD21', 'CBD22', 'mean_to_cbd', 'closest_cbd',
#        'w_tt'],
#       dtype='object')

# %%
tt.to_csv('../Data/weighted_tt.csv')
